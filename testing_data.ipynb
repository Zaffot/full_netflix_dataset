# %% [markdown]
# ## Testing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_path = "./data/full_netflix_dataset.csv"

# https://www.kaggle.com/datasets/octopusteam/full-netflix-dataset

# %%
full_netflix_dataset_df = pd.read_csv(data_path)

# %%
full_netflix_dataset_df
# Out:
#                                            title   type  \
# 0                              The Fifth Element  movie
# 1                              Kill Bill: Vol. 1  movie
# 2                                        Jarhead  movie
# 3                                     Unforgiven  movie
# 4          Eternal Sunshine of the Spotless Mind  movie
# ...                                          ...    ...
# 20191                                        NaN     tv
# 20192                                        NaN     tv
# 20193                                        NaN     tv
# 20194                                        NaN     tv
# 20195  Blippi's Ultimate Bounce House Challenges     tv
#
#                               genres  releaseYear      imdbId  \
# 0          Action, Adventure, Sci-Fi       1997.0   tt0119116
# 1            Action, Crime, Thriller       2003.0   tt0266697
# 2              Biography, Drama, War       2005.0   tt0418763
# ...

# %%
#social_network_ads_df = pd.read_csv(data_path)
#social_network_ads_df = pd.DataFrame(
    #data=np.c_[social_network_ads_df[['Age', 'EstimatedSalary']], social_network_ads_df['Purchased']],
    #columns=['Age', 'EstimatedSalary', 'Purchased']
#)

# %% [markdown]
# **Projektityö**
# Projektityö sisältää kolme pääosaa: datan esikäsittelyn, tilastollisten menetelmien soveltamisen ja keskeisten löydösten visualisoinnin. Datan monipuolisuuden varmistamiseksi jokaisen opiskelijan tulee jakaa linkki datasettiin, jota he käyttävät. Kaksi opiskelijaa ei saa käyttää samaa datasettiä. Tilastollisen analyysin tehokkuuden takaamiseksi on tärkeää varmistaa, että tietyt datasetin sarakkeet sisältävät numeerista dataa. Projektityö tulee suorittaa interaktiivisessa muistikirjassa, jossa on sekä Markdown- että Python-koodisoluja.
#
# **Projektityössä käytettävä datasetti:**
# - Et voi käyttää Titanic-datasettiä, jota on käsitelty materiaalissa.
# - Voit hankkia datasetin esimerkiksi Kagglesta (https://www.kaggle.com/datasets) tai muusta avoimesta lähteestä.
# - Datasetissä tulee olla riittävä määrä dataa, vähintään 2000 riviä.
#
# **Projektin esittelyvideo:**
# Jokaisen opiskelijan tulee luoda video, jossa he esittelevät löydöksensä.
#
# **Projektin palautus:**
# Jokainen opiskelija palauttaa Moodlessa videon, datasetin ja muistikirjatiedoston (.ipynb).
# Palauta .ipynb-tiedostosi sekä linkki videoon ja datasettiin.
#
# **Tehtävät ja aktiviteetit:**
# Käytä mielikuvitustasi ja luovuuttasi datasetin esikäsittelyssä ja analysoinnissa. Voit aloittaa seuraavista tehtävistä, mutta voit myös tutkia muita tapoja:
#
# **Datan esikäsittely**
# - Valitse datasetti ja tutustu siihen. Voit esimerkiksi tarkastella satunnaista näytettä datasta sekä rivien ja sarakkeiden määrää.
# - Tarkista, sisältääkö datasetti puuttuvia arvoja, ja laske puuttuvan datan osuus. Päätä kontekstin perusteella, mitä tehdä puuttuville arvoille, ja toteuta tarvittavat toimenpiteet.
# - Tunnista ja poista datasetistä päällekkäiset arvot.
# - Jaa yksi datasetin jatkuvaa numeerista dataa sisältävä sarake sopiviin luokkiin (käytä esimerkiksi `cut`- tai `qcut`-funktiota).
# - Tunnista datasetistä poikkeavat arvot (outlierit). Jos datasetissä ei ole poikkeavia arvoja, voit satunnaisesti muokata osaa datasta.
# - Päätä, mitä tehdä poikkeaville arvoille.
#
# **Dataobjektit ja attribuuttityypit**
# - Tulosta datasetistä sarakkeiden nimet, jotka edustavat nimellisiä attribuutteja.
# - Tulosta datasetistä sarakkeiden nimet, jotka edustavat binaarisia attribuutteja.
# - Tulosta datasetistä sarakkeiden nimet, jotka edustavat järjestettyjä attribuutteja (ordinal).
#
# **Perustilastot**
# Tee NumPyn avulla perustilastollisia operaatioita datasetille. Ohjeena voit laskea seuraavat:
# - Keskiarvo (Mean)
# - Mediaani
# - Keskiarvon hajonta (Standard Deviation)
# - Varianssi
# - Minimi- ja maksimiarvot
# - Summa ja tulo
#
# **Visualisointi**
# Käytä Matplotlibia erilaisten kaavioiden ja graafien luomiseen. Datasetistäsi ja analyysistäsi riippuen voit tehdä seuraavanlaisia visualisointeja:
# - Viivakaavio (Line Plot)
# - Hajontakaavio (Scatter Plot)
# - Pylväsdiagrammi (Bar Chart)
# - Histogrammi
# - Ympyrädiagrammi (Pie Chart)
# - Lämpökartta (Heatmap)
# - 3D-kaavio
